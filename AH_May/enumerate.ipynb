# %%
import numpy as np

# %%
list1 = ["cow","dog"]
var1 = "Jon"

# %%
en1 = enumerate(list1)
en2 = enumerate(var1)

# %%
print ("Return type:",type(list1))
print (list(enumerate(list1)))
# Out:
# Return type: <class 'list'>
# [(0, 'cow'), (1, 'dog')]

# %%
for i in en1:
    print(i)
    print(type(i))
# Out:
# (0, 'cow')
# <class 'tuple'>
# (1, 'dog')
# <class 'tuple'>

# %%
for key,value in enumerate(list1):
    print(key,value)
# Out:
# 0 cow
# 1 dog
