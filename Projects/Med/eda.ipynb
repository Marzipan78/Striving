# %%
import time
from IPython.display import clear_output
import numpy    as np
import pandas   as pd
import seaborn  as sns
import matplotlib.pyplot as plt
import sklearn  as skl

from sklearn import pipeline      # Pipeline
from sklearn import preprocessing # OrdinalEncoder, LabelEncoder
from sklearn import impute
from sklearn import compose
from sklearn import model_selection # train_test_split
from sklearn import metrics         # accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config

set_config(display='diagram') # Useful for display the pipeline

# %%
data = pd.read_csv('heart.csv')

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
data.sex.value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
data.cp.value_counts()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
data.chol.value_counts()
# Out:
# 204    6
# 197    6
# 234    6
# 269    5
# 212    5
#       ..
# 215    1
# 210    1
# 200    1
# 195    1
# 417    1
# Name: chol, Length: 152, dtype: int64

# %%
data.fbs.value_counts()
# Out:
# 0    258
# 1     45
# Name: fbs, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
x= data.drop(columns=['target'])
y = data['target']

# %%
data.keys()
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
num_vars = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca', 'thal']

# %%
num_4_treeModels = pipeline.Pipeline(steps=[
  ('imputer', impute.SimpleImputer(strategy='constant', fill_value=-9999))
])
tree_prepro = compose.ColumnTransformer(transformers=[
    ('num', num_4_treeModels, num_vars)
], remainder='drop') 
tree_prepro
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(fill_value=-9999,
#                                                                 strategy='constant'))]),
#                                  ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs',
#                                   'restecg', 'thalach', 'exang', 'oldpeak',
#                                   'slope', 'ca', 'thal'])])

# %%
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier

# %%
tree_classifiers = {
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees":   ExtraTreesClassifier(n_estimators=100),
  "Random Forest": RandomForestClassifier(n_estimators=100),
  "AdaBoost":      AdaBoostClassifier(n_estimators=100),
  "Skl GBM":       GradientBoostingClassifier(n_estimators=100),
  "Skl HistGBM":   HistGradientBoostingClassifier(max_iter=100),
  "XGBoost":       XGBClassifier(n_estimators=100),
  "LightGBM":      LGBMClassifier(n_estimators=100),
  
} 



   
tree_classifiers = {name: pipeline.make_pipeline(tree_prepro, model) for name, model in tree_classifiers.items()}
tree_classifiers["LightGBM"]
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=-9999,
#                                                                                  strategy='constant'))]),
#                                                   ['age', 'sex', 'cp',
#                                                    'trestbps', 'chol', 'fbs',
#                                                    'restecg', 'thalach',
#                                                    'exang', 'oldpeak', 'slope',
#                                                    'ca', 'thal'])])),
#                 ('lgbmclassifier', LGBMClassifier())])

# %%
x_train, x_val, y_train, y_val = model_selection.train_test_split(
    x, y,
    test_size=0.2,
    stratify = y,   
    random_state=4  
)

results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

for model_name, model in tree_classifiers.items():

    start_time = time.time()
    model.fit(x_train, y_train)
    total_time = time.time() - start_time
    
    pred = model.predict(x_val)
    
    results = results.append({"Model":    model_name,
                              "Accuracy": metrics.accuracy_score(y_val, pred)*100,
                              "Bal Acc.": metrics.balanced_accuracy_score(y_val, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
    
    results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
    results_ord.index += 1 
    
    clear_output(wait=True)
    display(results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d'))
# Out:
# <style  type="text/css" >
# #T_7c8a4_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.5%, transparent 88.5%);
#         }#T_7c8a4_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.0%, transparent 88.0%);
#         }#T_7c8a4_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.9%, transparent 86.9%);
#         }#T_7c8a4_row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.0%, transparent 86.0%);
#         }#T_7c8a4_row2_col1,#T_7c8a4_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 85.2%, transparent 85.2%);
#         }#T_7c8a4_row2_col2,#T_7c8a4_row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 84.5%, transparent 84.5%);
#         }#T_7c8a4_row4_col1,#T_7c8a4_row5_col1,#T_7c8a4_row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.6%, transparent 83.6%);
#         }#T_7c8a4_row4_col2,#T_7c8a4_row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.0%, transparent 83.0%);
#         }#T_7c8a4_row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.7%, transparent 82.7%);
#         }#T_7c8a4_row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.0%, transparent 82.0%);
#         }#T_7c8a4_row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.9%, transparent 80.9%);
#         }</style><table id="T_7c8a4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Bal Acc.</th>        <th class="col_heading level0 col3" >Time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7c8a4_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_7c8a4_row0_col0" class="data row0 col0" >Skl HistGBM</td>
#                         <td id="T_7c8a4_row0_col1" class="data row0 col1" >88.524590</td>
#                         <td id="T_7c8a4_row0_col2" class="data row0 col2" >88.041126</td>
#                         <td id="T_7c8a4_row0_col3" class="data row0 col3" >0.227358</td>
#             </tr>
#             <tr>
#                         <th id="T_7c8a4_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_7c8a4_row1_col0" class="data row1 col0" >AdaBoost</td>
#                         <td id="T_7c8a4_row1_col1" class="data row1 col1" >86.885246</td>
#                         <td id="T_7c8a4_row1_col2" class="data row1 col2" >85.984848</td>
#                         <td id="T_7c8a4_row1_col3" class="data row1 col3" >0.107749</td>
#             </tr>
#             <tr>
#                         <th id="T_7c8a4_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_7c8a4_row2_col0" class="data row2 col0" >Decision Tree</td>
#                         <td id="T_7c8a4_row2_col1" class="data row2 col1" >85.245902</td>
#                         <td id="T_7c8a4_row2_col2" class="data row2 col2" >84.469697</td>
#                         <td id="T_7c8a4_row2_col3" class="data row2 col3" >0.006016</td>
#             </tr>
#             <tr>
#                         <th id="T_7c8a4_level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_7c8a4_row3_col0" class="data row3 col0" >LightGBM</td>
#                         <td id="T_7c8a4_row3_col1" class="data row3 col1" >85.245902</td>
#                         <td id="T_7c8a4_row3_col2" class="data row3 col2" >84.469697</td>
#                         <td id="T_7c8a4_row3_col3" class="data row3 col3" >0.042885</td>
#             </tr>
#             <tr>
#                         <th id="T_7c8a4_level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_7c8a4_row4_col0" class="data row4 col0" >Extra Trees</td>
#                         <td id="T_7c8a4_row4_col1" class="data row4 col1" >83.606557</td>
#                         <td id="T_7c8a4_row4_col2" class="data row4 col2" >82.954545</td>
#                         <td id="T_7c8a4_row4_col3" class="data row4 col3" >0.086767</td>
#             </tr>
#             <tr>
#                         <th id="T_7c8a4_level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_7c8a4_row5_col0" class="data row5 col0" >Random Forest</td>
#                         <td id="T_7c8a4_row5_col1" class="data row5 col1" >83.606557</td>
#                         <td id="T_7c8a4_row5_col2" class="data row5 col2" >82.954545</td>
#                         <td id="T_7c8a4_row5_col3" class="data row5 col3" >0.102762</td>
#             </tr>
#             <tr>
#                         <th id="T_7c8a4_level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_7c8a4_row6_col0" class="data row6 col0" >XGBoost</td>
#                         <td id="T_7c8a4_row6_col1" class="data row6 col1" >83.606557</td>
#                         <td id="T_7c8a4_row6_col2" class="data row6 col2" >82.683983</td>
#                         <td id="T_7c8a4_row6_col3" class="data row6 col3" >0.078790</td>
#             </tr>
#             <tr>
#                         <th id="T_7c8a4_level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_7c8a4_row7_col0" class="data row7 col0" >Skl GBM</td>
#                         <td id="T_7c8a4_row7_col1" class="data row7 col1" >81.967213</td>
#                         <td id="T_7c8a4_row7_col2" class="data row7 col2" >80.898268</td>
#                         <td id="T_7c8a4_row7_col3" class="data row7 col3" >0.062870</td>
#             </tr>
#     </tbody></table>

# %%
skf = model_selection.StratifiedKFold(n_splits=10, shuffle=True, random_state=0)

results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

for model_name, model in tree_classifiers.items():    
        
    start_time = time.time()
    pred = model_selection.cross_val_predict(model, x, y, cv=skf)  
    total_time = time.time() - start_time
    
    results = results.append({"Model":    model_name,
                              "Accuracy": metrics.accuracy_score(y, pred)*100,
                              "Bal Acc.": metrics.balanced_accuracy_score(y, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)

    results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
    results_ord.index += 1 
    
    clear_output(wait=True)
    display(results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d'))
# Out:
# <style  type="text/css" >
# #T_2921a_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.5%, transparent 82.5%);
#         }#T_2921a_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.0%, transparent 82.0%);
#         }#T_2921a_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.2%, transparent 82.2%);
#         }#T_2921a_row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.9%, transparent 81.9%);
#         }#T_2921a_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.5%, transparent 81.5%);
#         }#T_2921a_row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.3%, transparent 81.3%);
#         }#T_2921a_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.5%, transparent 80.5%);
#         }#T_2921a_row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.0%, transparent 80.0%);
#         }#T_2921a_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.5%, transparent 79.5%);
#         }#T_2921a_row4_col2,#T_2921a_row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.2%, transparent 79.2%);
#         }#T_2921a_row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.9%, transparent 78.9%);
#         }#T_2921a_row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 76.9%, transparent 76.9%);
#         }#T_2921a_row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 76.5%, transparent 76.5%);
#         }#T_2921a_row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 74.3%, transparent 74.3%);
#         }#T_2921a_row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 74.1%, transparent 74.1%);
#         }</style><table id="T_2921a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Bal Acc.</th>        <th class="col_heading level0 col3" >Time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2921a_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_2921a_row0_col0" class="data row0 col0" >Random Forest</td>
#                         <td id="T_2921a_row0_col1" class="data row0 col1" >82.508251</td>
#                         <td id="T_2921a_row0_col2" class="data row0 col2" >81.982872</td>
#                         <td id="T_2921a_row0_col3" class="data row0 col3" >1.193810</td>
#             </tr>
#             <tr>
#                         <th id="T_2921a_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_2921a_row1_col0" class="data row1 col0" >Extra Trees</td>
#                         <td id="T_2921a_row1_col1" class="data row1 col1" >82.178218</td>
#                         <td id="T_2921a_row1_col2" class="data row1 col2" >81.916996</td>
#                         <td id="T_2921a_row1_col3" class="data row1 col3" >0.937495</td>
#             </tr>
#             <tr>
#                         <th id="T_2921a_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_2921a_row2_col0" class="data row2 col0" >Skl GBM</td>
#                         <td id="T_2921a_row2_col1" class="data row2 col1" >81.518152</td>
#                         <td id="T_2921a_row2_col2" class="data row2 col2" >81.251647</td>
#                         <td id="T_2921a_row2_col3" class="data row2 col3" >0.684202</td>
#             </tr>
#             <tr>
#                         <th id="T_2921a_level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_2921a_row3_col0" class="data row3 col0" >Skl HistGBM</td>
#                         <td id="T_2921a_row3_col1" class="data row3 col1" >80.528053</td>
#                         <td id="T_2921a_row3_col2" class="data row3 col2" >80.046113</td>
#                         <td id="T_2921a_row3_col3" class="data row3 col3" >2.689787</td>
#             </tr>
#             <tr>
#                         <th id="T_2921a_level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_2921a_row4_col0" class="data row4 col0" >LightGBM</td>
#                         <td id="T_2921a_row4_col1" class="data row4 col1" >79.537954</td>
#                         <td id="T_2921a_row4_col2" class="data row4 col2" >79.196311</td>
#                         <td id="T_2921a_row4_col3" class="data row4 col3" >0.511633</td>
#             </tr>
#             <tr>
#                         <th id="T_2921a_level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_2921a_row5_col0" class="data row5 col0" >XGBoost</td>
#                         <td id="T_2921a_row5_col1" class="data row5 col1" >79.207921</td>
#                         <td id="T_2921a_row5_col2" class="data row5 col2" >78.893281</td>
#                         <td id="T_2921a_row5_col3" class="data row5 col3" >0.919541</td>
#             </tr>
#             <tr>
#                         <th id="T_2921a_level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_2921a_row6_col0" class="data row6 col0" >AdaBoost</td>
#                         <td id="T_2921a_row6_col1" class="data row6 col1" >76.897690</td>
#                         <td id="T_2921a_row6_col2" class="data row6 col2" >76.534914</td>
#                         <td id="T_2921a_row6_col3" class="data row6 col3" >1.238721</td>
#             </tr>
#             <tr>
#                         <th id="T_2921a_level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_2921a_row7_col0" class="data row7 col0" >Decision Tree</td>
#                         <td id="T_2921a_row7_col1" class="data row7 col1" >74.257426</td>
#                         <td id="T_2921a_row7_col2" class="data row7 col2" >74.110672</td>
#                         <td id="T_2921a_row7_col3" class="data row7 col3" >0.109737</td>
#             </tr>
#     </tbody></table>
