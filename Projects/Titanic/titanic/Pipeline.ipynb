# %% [markdown]
# ## Imports

# %%
import time
from IPython.display import clear_output
import numpy    as np
import pandas   as pd
import seaborn  as sb
import matplotlib.pyplot as plt
import sklearn  as skl

from sklearn import pipeline      # Pipeline
from sklearn import preprocessing # OrdinalEncoder, LabelEncoder
from sklearn import impute
from sklearn import compose
from sklearn import model_selection # train_test_split
from sklearn import metrics         # accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config

from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier

set_config(display='diagram') # Useful for display the pipeline

print("Pandas  ", pd.__version__)
print("Sklearn ", skl.__version__) # Try to use 0.24
# Out:
# Pandas   1.1.3
# Sklearn  0.23.2

# %% [markdown]
# ## Load data

# %%
df      = pd.read_csv("train.csv", index_col='PassengerId')
df_test = pd.read_csv("test.csv",  index_col='PassengerId')

print("Train DataFrame:", df.shape)
print("Test DataFrame: ", df_test.shape)
# Out:
# Train DataFrame: (891, 11)
# Test DataFrame:  (418, 10)

# %% [markdown]
# ## Check missings

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Pclass        0
# Name          0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
get_Title_from_Name = lambda name: name.split(',')[1].split('.')[0].strip()


df['Title']      = df['Name'].map(get_Title_from_Name)
df_test['Title'] = df_test['Name'].map(get_Title_from_Name)

# %%
title_dictionary = {
    "Capt": "Officer",
    "Col": "Officer",
    "Major": "Officer",
    "Jonkheer": "Royalty",
    "Don": "Royalty",
    "Sir" : "Royalty",
    "Dr": "Officer",
    "Rev": "Officer",
    "the Countess":"Royalty",
    "Mme": "Mrs",
    "Mlle": "Miss",
    "Ms": "Mrs",
    "Mr" : "Mr",
    "Mrs" : "Mrs",
    "Miss" : "Miss",
    "Master" : "Master",
    "Lady" : "Royalty"
}

# %%
# Use map to apply the prevous dict

df["Title"] = df.Title.map(title_dictionary)
df_test["Title"] = df_test.Title.map(title_dictionary)

# %% [markdown]
# # Preprocessing
# For X data, notice that...
# - We drop Survived because is the target variable
# - We drop Name because we have extracted the Title: Mr, Mrs, ...
# - We drop Ticket because it has no information -> see df.Ticket.nunique()
# - We drop Cabin because it has a lot of missings (77% are missings)
#
# Then, we identify **numerical** variables and **categorical** variables,

# %%
x = df.drop(columns=["Survived", 'Name', 'Ticket', 'Cabin']) # X DATA (WILL BE TRAIN+VALID DATA)
y = df["Survived"] # 0 = No, 1 = Yes

x_test = df_test.drop(columns=['Name', 'Ticket', 'Cabin']) # # X_TEST DATA (NEW DATA)

# %%
cat_vars  = ['Sex', 'Embarked', 'Title']         # x.select_dtypes(include=[object]).columns.values.tolist()
num_vars  = ['Pclass', 'SibSp', 'Parch', 'Fare', 'Age'] # x.select_dtypes(exclude=[object]).columns.values.tolist()

print("\nNumerical features:\n", num_vars)
print("\nCategorical features:\n", cat_vars)
# Out:
# Numerical features:
#  ['Pclass', 'SibSp', 'Parch', 'Fare', 'Age']
#
# Categorical features:
#  ['Sex', 'Embarked', 'Title']

# %% [markdown]
# # Creating The Pipeline

# %%
num_4_treeModels = pipeline.Pipeline(steps=[
  ('imputer', impute.SimpleImputer(strategy='constant', fill_value=-9999))
])

cat_4_treeModels = pipeline.Pipeline(steps=[
   ('imputer', impute.SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', preprocessing.OneHotEncoder(handle_unknown='ignore')) # specify unknowns 
])

tree_prepro = compose.ColumnTransformer(transformers=[
    ('num', num_4_treeModels, num_vars),
    ('cat', cat_4_treeModels, cat_vars),
], remainder='drop') # Drop other vars not specified in num_vars or cat_vars

tree_prepro
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(fill_value=-9999,
#                                                                 strategy='constant'))]),
#                                  ['Pclass', 'SibSp', 'Parch', 'Fare', 'Age']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['Sex', 'Embarked', 'Title'])])

# %%
tree_classifiers = {
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees":   ExtraTreesClassifier(n_estimators=100),
  "Random Forest": RandomForestClassifier(n_estimators=100),
  "AdaBoost":      AdaBoostClassifier(n_estimators=100),
  "Skl GBM":       GradientBoostingClassifier(n_estimators=100),
  "Skl HistGBM":   HistGradientBoostingClassifier(max_iter=100),
  "XGBoost":       XGBClassifier(n_estimators=100),
  "LightGBM":      LGBMClassifier(n_estimators=100),
  "CatBoost":      CatBoostClassifier(n_estimators=100),
} 



   
tree_classifiers = {name: pipeline.make_pipeline(tree_prepro, model) for name, model in tree_classifiers.items()}
tree_classifiers["LightGBM"]
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=-9999,
#                                                                                  strategy='constant'))]),
#                                                   ['Pclass', 'SibSp', 'Parch',
#                                                    'Fare', 'Age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Sex', 'Embarked',
#                                                    'Title'])])),
#                 ('lgbmclassifier', LGBMClassifier())])

# %%
x_train, x_val, y_train, y_val = model_selection.train_test_split(
    x, y,
    test_size=0.2,
    stratify = y,   
    random_state=4  
)

results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

for model_name, model in tree_classifiers.items():

    start_time = time.time()
    model.fit(x_train, y_train)
    total_time = time.time() - start_time
    
    pred = model.predict(x_val)
    
    results = results.append({"Model":    model_name,
                              "Accuracy": metrics.accuracy_score(y_val, pred)*100,
                              "Bal Acc.": metrics.balanced_accuracy_score(y_val, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
    
    results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
    results_ord.index += 1 
    
    clear_output(wait=True)
    display(results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d'))
# Out:
# <style  type="text/css" >
# #T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.3%, transparent 88.3%);
#         }#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.9%, transparent 86.9%);
#         }#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 85.5%, transparent 85.5%);
#         }#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row1_col2,#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row4_col1,#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 84.4%, transparent 84.4%);
#         }#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row2_col1,#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 84.9%, transparent 84.9%);
#         }#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 84.2%, transparent 84.2%);
#         }#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.7%, transparent 83.7%);
#         }#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.2%, transparent 83.2%);
#         }#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.7%, transparent 82.7%);
#         }#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row6_col1,#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.1%, transparent 82.1%);
#         }#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.9%, transparent 81.9%);
#         }#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.3%, transparent 80.3%);
#         }#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.0%, transparent 81.0%);
#         }#T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.7%, transparent 79.7%);
#         }</style><table id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Bal Acc.</th>        <th class="col_heading level0 col3" >Time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row0_col0" class="data row0 col0" >XGBoost</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row0_col1" class="data row0 col1" >88.268156</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row0_col2" class="data row0 col2" >86.943347</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row0_col3" class="data row0 col3" >0.210437</td>
#             </tr>
#             <tr>
#                         <th id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row1_col0" class="data row1 col0" >LightGBM</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row1_col1" class="data row1 col1" >85.474860</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row1_col2" class="data row1 col2" >84.400527</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row1_col3" class="data row1 col3" >0.134640</td>
#             </tr>
#             <tr>
#                         <th id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row2_col0" class="data row2 col0" >AdaBoost</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row2_col1" class="data row2 col1" >84.916201</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row2_col2" class="data row2 col2" >84.216074</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row2_col3" class="data row2 col3" >0.157164</td>
#             </tr>
#             <tr>
#                         <th id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row3_col0" class="data row3 col0" >Skl HistGBM</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row3_col1" class="data row3 col1" >84.916201</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row3_col2" class="data row3 col2" >83.675889</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row3_col3" class="data row3 col3" >1.204287</td>
#             </tr>
#             <tr>
#                         <th id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row4_col0" class="data row4 col0" >Skl GBM</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row4_col1" class="data row4 col1" >84.357542</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row4_col2" class="data row4 col2" >83.221344</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row4_col3" class="data row4 col3" >0.096201</td>
#             </tr>
#             <tr>
#                         <th id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row5_col0" class="data row5 col0" >CatBoost</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row5_col1" class="data row5 col1" >84.357542</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row5_col2" class="data row5 col2" >82.681159</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row5_col3" class="data row5 col3" >0.366155</td>
#             </tr>
#             <tr>
#                         <th id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row6_col0" class="data row6 col0" >Decision Tree</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row6_col1" class="data row6 col1" >82.122905</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row6_col2" class="data row6 col2" >81.943347</td>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row6_col3" class="data row6 col3" >0.012968</td>
#             </tr>
#             <tr>
#                         <th id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_6d00aa29_add7_11eb_8a35_ae6b7f9f0e40row7_col0" class="data row

# %%
skf = model_selection.StratifiedKFold(n_splits=100, shuffle=True, random_state=0)

results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

for model_name, model in tree_classifiers.items():    
        
    start_time = time.time()
    pred = model_selection.cross_val_predict(model, x, y, cv=skf)  
    total_time = time.time() - start_time
    
    results = results.append({"Model":    model_name,
                              "Accuracy": metrics.accuracy_score(y, pred)*100,
                              "Bal Acc.": metrics.balanced_accuracy_score(y, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)

    results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
    results_ord.index += 1 
    
    clear_output(wait=True)
    display(results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d'))
# Out:
# <style  type="text/css" >
# #T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row0_col1,#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.2%, transparent 83.2%);
#         }#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.1%, transparent 81.1%);
#         }#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.8%, transparent 81.8%);
#         }#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.9%, transparent 82.9%);
#         }#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.3%, transparent 81.3%);
#         }#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row3_col1,#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.5%, transparent 82.5%);
#         }#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.4%, transparent 81.4%);
#         }#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.2%, transparent 80.2%);
#         }#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.0%, transparent 82.0%);
#         }#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.5%, transparent 80.5%);
#         }#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.4%, transparent 80.4%);
#         }#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.9%, transparent 78.9%);
#         }#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row7_col1,#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.8%, transparent 79.8%);
#         }#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.8%, transparent 78.8%);
#         }#T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.4%, transparent 78.4%);
#         }</style><table id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Bal Acc.</th>        <th class="col_heading level0 col3" >Time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row0_col0" class="data row0 col0" >Skl GBM</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row0_col1" class="data row0 col1" >83.164983</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row0_col2" class="data row0 col2" >81.102004</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row0_col3" class="data row0 col3" >11.979445</td>
#             </tr>
#             <tr>
#                         <th id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row1_col0" class="data row1 col0" >Skl HistGBM</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row1_col1" class="data row1 col1" >83.164983</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row1_col2" class="data row1 col2" >81.763493</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row1_col3" class="data row1 col3" >180.330756</td>
#             </tr>
#             <tr>
#                         <th id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row2_col0" class="data row2 col0" >LightGBM</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row2_col1" class="data row2 col1" >82.940516</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row2_col2" class="data row2 col2" >81.250599</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row2_col3" class="data row2 col3" >20.586973</td>
#             </tr>
#             <tr>
#                         <th id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row3_col0" class="data row3 col0" >AdaBoost</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row3_col1" class="data row3 col1" >82.491582</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row3_col2" class="data row3 col2" >81.382418</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row3_col3" class="data row3 col3" >17.427055</td>
#             </tr>
#             <tr>
#                         <th id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row4_col0" class="data row4 col0" >CatBoost</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row4_col1" class="data row4 col1" >82.491582</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row4_col2" class="data row4 col2" >80.224811</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row4_col3" class="data row4 col3" >28.358676</td>
#             </tr>
#             <tr>
#                         <th id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row5_col0" class="data row5 col0" >XGBoost</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row5_col1" class="data row5 col1" >82.042649</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row5_col2" class="data row5 col2" >80.522002</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row5_col3" class="data row5 col3" >26.336927</td>
#             </tr>
#             <tr>
#                         <th id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row6_col0" class="data row6 col0" >Random Forest</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row6_col1" class="data row6 col1" >80.359147</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row6_col2" class="data row6 col2" >78.935385</td>
#                         <td id="T_2af56f22_add8_11eb_83ce_ae6b7f9f0e40row6_col3" class="data row6 col3" >17.115105</td>
#             </tr>
#             <tr>
#                         <th id="T_2af56f22_add8_11eb_83ce_ae6b7f9f

# %%
best_model =   tree_classifiers["Skl GBM"] 
best_model.fit(x,y)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=-9999,
#                                                                                  strategy='constant'))]),
#                                                   ['Pclass', 'SibSp', 'Parch',
#                                                    'Fare', 'Age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Sex', 'Embarked',
#                                                    'Title'])])),
#                 ('gradientboostingclassifier', GradientBoostingClassifier())])

# %%
test_pred = best_model.predict(x_test)

# %%
sub = pd.DataFrame(test_pred, index=x_test.index, columns=["Survived"])
sub.head()
# Out:
#              Survived
# PassengerId
# 892                 0
# 893                 0
# 894                 0
# 895                 0
# 896                 0

# %%
sub.to_csv("sub.csv")

# %%
# !kaggle competitions submit -c titanic -f sub.csv -m "My submission message"
# Out:
# 'kaggle' is not recognized as an internal or external command,
# operable program or batch file.
