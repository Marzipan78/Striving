# %%
import aflr

# %%
dir(aflr)
# Out:
# ['Mastering',
#  'Script',
#  'Sound',
#  'Speech',
#  'Voice',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'api_base',
#  'api_key',
#  'api_request',
#  'api_resources',
#  'api_version',
#  'app_info',
#  'client_id',
#  'default_http_client',
#  'enable_telemetry',
#  'helper_classes',
#  'log',
#  'mastering',
#  'max_network_retries',
#  'proxy',
#  'script',
#  'sound',
#  'speech',
#  'upload_api_base',
#  'verify_ssl_certs',
#  'voice']

# %%
dir(aflr.Script())
# Out:
# ['OBJECT_NAME',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api_key_checker',
#  '_build_header',
#  '_download_request',
#  '_expanded_raise_for_status',
#  '_get_request',
#  '_post_request',
#  'config_test',
#  'create',
#  'get_random_text',
#  'list',
#  'random_url',
#  'resource_path',
#  'retrieve']

# %%
help(aflr)
# Out:
# Help on Script in module aflr.api_resources.script object:
#
# class Script(aflr.helper_classes.ListableResource, aflr.helper_classes.CreatableResource, aflr.helper_classes.RetrievableResource)
#  |  Method resolution order:
#  |      Script
#  |      aflr.helper_classes.ListableResource
#  |      aflr.helper_classes.CreatableResource
#  |      aflr.helper_classes.RetrievableResource
#  |      aflr.api_request.APIRequest
#  |      builtins.object
#  |
#  |  Class methods defined here:
#  |
#  |  get_random_text(category=None) from builtins.type
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  OBJECT_NAME = 'script'
#  |
#  |  random_url = '/script/random'
#  |
#  |  resource_path = '/script'
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from aflr.helper_classes.ListableResource:
#  |
#  |  list(**args) from builtins.type
#  |
# ...
