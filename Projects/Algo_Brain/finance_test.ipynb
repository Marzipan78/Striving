# %%
import numpy as np

# %%
S, ru, rd, q = 150, 15, 7, 0.73
Su = S*(1+ru/100) 
Sd = S*(1-rd/100) 
F = q*Su+(1-q)*Sd 
F
# Out:
# 163.59

# %%
P0,c,P1 = 97,9,102
P05 = P0/100 
P01 = (P1 - P05*c/2)/(100 + c/2) 
f = 2*(P05/P01 - 1)*100 
f
# Out:
# 7.640702616889428

# %%
import numpy as np 

de,fe,rus = 1.89,1.75,1.11 # fe = de * np.exp((rus-reur)/100/2) 
reur = 100*(rus/100 - 2*np.log(fe/de))
reur
# Out:
# 16.502208227225665
