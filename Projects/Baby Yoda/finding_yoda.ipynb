# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# %%
planets = pd.read_csv('planet.csv')

# %%
pca = PCA()
planets_fitted = pca.fit_transform(planets)
pca_df = pd.DataFrame(data = planets_fitted)
i_variance = pca.explained_variance_ratio_

# %%
sns.barplot(x=[i for i in range(len(i_variance))], y=i_variance)
plt.title("Principal component analysis")
plt.xlabel('Columns')
plt.ylabel('Explained variance in %')
plt.show()

# %%
plt.scatter(pca_df.iloc[:,0], pca_df.iloc[:,1],alpha =0.2)
plt.scatter(pca_df.iloc[:,0].mean(),pca_df.iloc[:,1].mean())
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Data and its center')
# Out:
# Text(0.5, 1.0, 'Data and its center')

# %%
x_mean=pca_df.iloc[:,0].mean()
y_mean=pca_df.iloc[:,1].mean()

# %%
dist = np.sqrt((pca_df.iloc[:,0]-x_mean)**2 + (pca_df.iloc[:,1]-y_mean)**2)
row_sol = np.where(dist==min(dist))[0][0]
row_test = np.where(dist==max(dist))[0][0]

# %%
solution = pca_df.iloc[row_sol, :2]
solution
# Out:
# 0   -0.146186
# 1   -0.031480
# Name: 684, dtype: float64

# %%
plt.scatter(pca_df.iloc[:,0], pca_df.iloc[:,1],alpha =0.2)
plt.scatter(pca_df.iloc[:,0].mean(),pca_df.iloc[:,1].mean())
plt.scatter(solution[0], solution[1],c='purple')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Data, its center and the closest point to it')
# Out:
# Text(0.5, 1.0, 'Data, its center and the closest point to it')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4fdc1fa5-6f26-4ec2-b2d3-ce107e824e55' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
