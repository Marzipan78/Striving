# %%
import subprocess
from ibm_watson import SpeechToTextV1
from ibm_watson.websocket import RecognizeCallback, AudioSource
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
command = 'ffmpeg -i ytest.mp4 -ab 160k -ar 44100 -vn ytest.wav'
subprocess.call(command, shell=True)
# Out:
# 1

# %%
apikey = "dWuZI7x471k-Y1pvOD6cnRK44NfTAnUfRsN6Wt0xEKOw"
url = "https://api.au-syd.speech-to-text.watson.cloud.ibm.com/instances/ddaf634b-beee-47ab-b519-bd9828a2edb5"

# %%
# Setup service
authenticator = IAMAuthenticator(apikey)
stt = SpeechToTextV1(authenticator=authenticator)
stt.set_service_url(url)

# %%
with open('ytest.wav', 'rb') as f:
    res = stt.recognize(audio=f, content_type='audio/wav', model='en-GB_NarrowbandModel', continuous=True).get_result()

# %%
text = [result['alternatives'][0]['transcript'].rstrip() + '.\n' for result in res['results']]

# %%
text = [para[0].title() + para[1:] for para in text]
transcript = ''.join(text)
with open('output.txt', 'w') as out:
    out.writelines(transcript)

# %%
transcript
# Out:
# "Let's get more on that breaking news you can see the bottom of the screen George Russell to replace felt three bata in the Mercedes thing from next season delighted the fate that we get reaction to it Damon hill joins us %HESITATION right now very good morning to you daily how bigger movies this from Russell.\nThe catch yourself electron beam as a young driver that early on so you can you can show me what job and we saw a little bit about what you can do when when Lewis got.\nCode in the address bar I reckon he was funny and.\nThat indicated not not the only in the guest house very very good job roughly so he's done is on there if you know the same family but now he'll be fully into Kansi in the hot seat now right alongside hoping you know but winning is driver in his group.\nYes %HESITATION he certainly services apprenticeship has may tell us a bit about him %HESITATION no British line of a course for them so what we bring to the team's.\n%HESITATION I believe brilliant normally ma
# ...
