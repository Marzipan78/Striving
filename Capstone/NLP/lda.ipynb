# %%
import numpy as np
import pandas as pd



import spacy
#from spacy.lemmatizer import Lemmatizer
from spacy.lang.en.stop_words import STOP_WORDS
import en_core_web_sm
from spacy.language import Language

from tqdm import tqdm_notebook as tqdm
from pprint import pprint

# %%
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
# Out:
# C:\Users\pgsin\anaconda3\envs\skippy\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\pgsin\Documents\AI_ENGINEERING\Striving\Capstone\NLP

# %%
# # Function to Get the current 
# # working directory
# def current_path():
#     print("Current working directory before")
#     print(os.getcwd())
#     print()
   
   
# # Driver's code
# # Printing CWD before
# current_path()
   
# # Changing the CWD
# os.chdir('../')
   
# # Printing CWD after
# 
os.chdir('../')
print("Current working directory after")
print(os.getcwd())
# Out:
# Current working directory after
# c:\Users\pgsin\Documents\AI_ENGINEERING\Striving\Capstone

# %%
nlp= spacy.load("en_core_web_sm")

# %%
for word in STOP_WORDS:
    lexeme = nlp.vocab[word]
    lexeme.is_stop = True

# %%
@Language.component("lemmy")
def lemmatizer(doc):
    # This takes in a doc of tokens from the NER and lemmatizes them. 
    # Pronouns (like "I" and "you" get lemmatized to '-PRON-', so I'm removing those.
    doc = [token.lemma_ for token in doc if token.lemma_ != '-PRON-']
    doc = u' '.join(doc)
    return nlp.make_doc(doc)
    
@Language.component("rstp")
def remove_stopwords(doc):
    # This will remove stopwords and punctuation.
    # Use token.text to return strings, which we'll need for Gensim.
    doc = [token.text for token in doc if token.is_stop != True and token.is_punct != True]
    return doc


nlp.add_pipe("lemmy",after='ner')
nlp.add_pipe("rstp", last=True)
# Out:
# <function __main__.remove_stopwords(doc)>

# %%
with open("d2d_laptop.txt") as f:
    lines = f.readlines()
    #print(lines)

# %%
doc_list = []
# Iterates through each article in the corpus.
for doc in tqdm(lines):
    # Passes that article through the pipeline and adds to a new list.
    pr = nlp(doc)
    doc_list.append(pr)
# Out:
# C:\Users\pgsin\AppData\Local\Temp/ipykernel_20308/2979821374.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for doc in tqdm(lines):
#   0%|          | 0/246 [00:00<?, ?it/s]

# %%
doc_list
# Out:
# [['right', 'laptop', '\n'],
#  ['650', 'fantastic', '\n'],
#  ['month', 'ago', 'announce', '\n'],
#  ['laptop', 'game', '\n'],
#  ['impression', 'like', 'okay', 'good', '\n'],
#  ['stuff', '\n'],
#  ['attempt', '\n'],
#  ['stuff', 'right', 'laptop', '\n'],
#  ['ve', 'expect', '\n'],
#  ['good', 'great', 'right', '\n'],
#  ['come', 'available', 'like', 'ta', '\n'],
#  ['thing', '\n'],
#  ['\n'],
#  ['remarkably', 'good', 'money', '\n'],
#  ['let', 'okay', 'thing', '\n'],
#  ['initial', '\n'],
#  ['reaction', 'like', 'run', '\n'],
#  ['ad', 'right', '\n'],
#  ['price', 'low', 've', 'run', '\n'],
#  ['bloatware', 'crap', '\n'],
#  ['people', 'want', 'people', 'need', '\n'],
#  ['company', '\n'],
#  ['laptop', 'company', '\n'],
#  ['know', 'norton', 'mcafee', '\n'],
#  ['crap', 'want', 'expect', '\n'],
#  ['fill', '\n'],
#  ['plain', 'blank', '\n'],
#  ['slate', 'window', '10', 'like', '\n'],
#  ['point', '\n'],
#  ['idea', 'run', 'thing', '\n'],
#  ['650', 'buck', 'let', 'talk', '\n'],
#  ['build', 'thin', 'machine', 'aluminum', '\n'],
#  ['device', 'build', '\n'],
#  ['rough', 'edge', 'polished', '\n'],
#  ['properly', 'thing', '\n'],
#  ['metal', 'device', 'inexpensive', '\n'],
#  ['quick', 'way', '\n'],
#  ['common', 'way', 'cut', 'cost', 'right', '\n'],
#  ['leave', 'edge', 'rough', 'leave', '\n'],
#  ['panel', 'unpolishe', '\n'],
#  ['company', '\n'],
#  ['properly', 'machine', 'properly', '\n'],
#  ['finished', 'product', 'weird', '\n'],
#  ['price', 'point', 'fairly', '\n'],
#  ['prominent', 'realme', 'logo', '\n'],
#  ['gon', 'na', 'like', 'screen', '\n'],
#  ['flex', 'slight', 'solid', '\n'],
#  ['tanky', 'machine', 'uh', 'thing', 'want', '\n'],
#  ['mention', 'hinge', '\n'],
#  ['hand', 'openable', 'mention', '\n'],
#  ['video', 'know', 'talk', '\n'],
#  ['ability', 'inability', '\n'],
#  ['device', 'people', 'flip', 'open', '\n'],
#  ['hand', '\n'],
#  ['super', 'important', 'right', 'like', '\n'],
#  ['people', 'lift', 'hinge', '\n'],
#  ['hand', 'point', 'fact', '\n'],
#  ['good', 'time', '\n'],
#  ['engineer', 'tune', 'hinge', 'right', '\n'],
#  ['openable', 'hand', 'right', '\n'],
#  ['tight', '\n'],
#  ['loose', 'flop', '\n'],
#  ['probably', '\n'],
#  ['point', 'real', 'device', 've', '\n'],
#  ['like', 'okay', 'kind', 'cut', 'corner', '\n'],
#  ['spend', 'time', '\n'],
#  ['\n'],
#  ['happen', 'tier', 'device', '\n'],
#  ['properly', 'tune', 'hand', 'openable', 'hinge', '\n'],
#  ['okay', 'screen', 'nice', '\n'],
#  ['aspect', 'ratio', 'high', 'res', '\n'],
#  ['good', 'brightness', 'good', 'color', '\n'],
#  ['nice', 'screen', '60', '\n'],
#  ['hertz', 'panel', 'like', 'high', '\n'],
#  ['refresh', 'gaming', 'display', '\n'],
#  ['glossy', 'finish', 'look', '\n'],
#  ['reflectivity', 'like', '\n'],
#  ['touch', 'screen', 'like', '\n'],
#  ['regular', 'screen', 'reflective', '\n'],
#  ['surface', 'kind', '\n'],
#  ['coat', 'reduce', 'reflection', '\n'],
#  ['use', 'matte', 'screen', '\n'],
#  ['reflective', 'screen', 'kind', 'like', '\n'],
#  ['macbook', 'thing', 'macbook', '\n'],
#  ['like', 'end', '\n'],
#  ['yeah', '\n'],
#  ['mean', '\n'],
#  ['macbook', 'aesthetic', 'um', 'oh', '\n'],
#  ['webcam', '720p', 'great', '\n'],
#  ['webcam', 'kind', 'job', '\n'],
#  ['need', 'rubber', 'trim', '\n'],
#  ['run', 'edge', 'screen', '\n'],
#  ['company', '\n'],
#  ['skimp', 'like', '\n'],
#  ['corner', 'cut', '\n'],
#  ['choose', 'cut', 'close', '\n'],
#  ['rubber', 'trim', 'laptop', '\n'],
#  ['nice', '\n'],
#  ['thump', 'sound', 'okay', 'keyboard', 'open', '\n'],
#  ['thing', 'right', 'uh', 'right', 'oh', '\n'],
#  ['thing', 'hinge', 'thing', '\n'],
#  ['like', 'perfectly', '\n'],
#  ['180', 'like', 'close', 'maybe', '\n'],
#  ['177', 'degree', 'uh', 'yeah', 'pretty', '\n'],
#  ['close', '\n'],
#  ['flat', 'open', 'look', '\n'],
#  ['okay', 'keyword', 'keyboard', '\n'],
#  ['model', 'term', 'layout', '\n'],
#  ['macbook', 'keyboard', 'texture', '\n'],
#  ['key', 'reminiscent', 'macbook', '\n'],
#  ['type', 'macbook', 'keyboard', '\n'],
#  ['feel', 'like', '\n'],
#  ['soft', 'responsive', '\n'],
#  ['keyboard', 'fast', 'type', '\n'],
#  ['personally', 'like', 'think', '\n'],
#  ['people', 'enjoy', 'keyboard', '\n'],
#  ['use', 'quickly', 'trackpad', '\n'],
#  ['like', 'macbook', 'whatsoever', 'think', '\n'],
#  ['plastic', 'surface', 'look', '\n'],
#  ['like', 'press', 'material', '\n'],
#  ['find', '\n'],
#  ['knife', 'try', '\n'],
#  ['scratch', 'able', 'scratch', '\n'],
#  ['mean', 'plastic', '\n'],
#  ['good', 'test', 'think', '\n'],
#  ['plastic', 'trackpad', '\n'],
#  ['surface', 'texture', 'okay', '\n'],
#  ['click', 'mechanic', 'amazing', '\n'],
#  ['average', 'trackpad', '\n'],
#  ['right', 'power', 'button', '\n'],
#  ['fingerprint', 'sensor', 'build', '\n'],
#  ['let', 'talk', 'performance', '\n'],
#  ['come', 'i3', 'i5', '\n'],
#  ['i5', 'perform', 'exactly', 'like', '\n'],
#  ['expect', 'device', 'like', '\n'],
#  ['cool', 'properly', 'fan', 'super', '\n'],
#  ['loud', 'interesting', '\n'],
#  ['note', 'pop', 'open', '\n'],
#  ['fan', 'normally', 'device', '\n'],
#  ['like', 'kind', 'form', 'factor', '\n'],
#  ['kind', 'chip', 'single', 'fan', '\n'],
#  ['like', 'competitor', 'think', '\n'],
#  ['single', 'fan', 'solution', 'dual', '\n'],
#  ['fan', 'sure', 'like', 'cost', '\n'],
#  ['thing', '\n'],
#  ['notice', 'inside', '\n'],
#  ['single', 'nvme', '\n'],
#  ['replace', 'wi', 'fi', 'card', '\n'],
#  ['replace', 'ram', 'bake', '\n'],
#  ['motherboard', 'unfortunately', '\n'],
#  ['upgrade', 'battery', '\n'],
#  ['56', 'watt', 'hour', 'super', 'small', '\n'],
#  ['like', 'device', 'like', 'kind', '\n'],
#  ['average', 'battery', '\n'],
#  ['life', 'little', 'bit', 'short', '\n'],
#  ['half', 'seven', 'hour', 'device', '\n'],
#  ['regular', 'testing', '\n'],
#  ['feeling', '\n'],
#  ['reason', 'low', '\n'],
#  ['like', 'hardware', '\n'],
#  ['software', 'feel', 'like', '\n'],
#  ['company', 'like', 'manufacturer', '\n'],
#  ['laptop', 'spend', 'time', '\n'],
#  ['software', 'tune', 'know', '\n'],
#  ['synergy', 'battery', '\n'],
#  ['energy', 'consumption', 'think', '\n'],
#  ['battery', 'life', 'kind', '\n'],
#  ['battery', 'size', 'company', '\n'],
#  ['feel', 'like', '\n'],
#  ['improve', '\n'],
#  ['right', 'run', 'couple', 'time', '\n'],
#  ['seven', 'little', 'bit', 'shy', 'seven', '\n'],
#  ['hour', '56', 'watt', 'hour', 'battery', 'okay', '\n'],
#  ['port', 'left', '\n'],
#  ['usbc', 'right', '\n'],
#  ['usb', 'note', 'usb', 'c', 'port', '\n'],
#  ['i5', 'variant', 'thunderbolt', '\n'],
#  ['4', 'compatible', 'i3', 'version', '\n'],
#  ['regular', 'usb', 'c', 'port', '\n'],
#  ['depend', 'need', 'kind', '\n'],
#  ['connectivity', 'look', '\n'],
#  ['adjustment', 'base', '\n'],
#  ['\n'],
#  ['yeah', 'think', 'people', 'usb', 'c', '\n'],
#  ['probably', 'good', 'gon', 'na', 'wrap', '\n'],
#  ['video', 'guess', 'thing', '\n'],
#  ['gon', 'na', 'talk', 'thing', '\n'],
#  ['like', 'device', 'thing', '\n'],
#  ['think', 'kind', '\n'],
#  ['differently', 'thing', 'like', '\n'],
#  ['price', '650', 'buck', 'base', '\n'],
#  ['\n'],
#  ['remarkably', 'good', 'kind', '\n'],
#  ['value', 'kind', 'build', 'quality', '\n'],
#  ['ve', 'look', 've', 'try', '\n'],
#  ['strange', 'able', '\n'],
#  ['pull', '\n'],
#  ['iteration', 'build', '\n'],
#  ['kick', 'ass', 'screen', 'good', '\n'],
#  ['performance', 'good', 'keyboard', '\n'],
#  ['thing', 'lack', '\n'],
#  ['trackpad', 'feel', 'like', '\n'],
#  ['improve', 'thing', '\n'],
#  ['like', '\n'],
#  ['clearly', 'macbook', 'clone', 'right', '\n'],
#  ['opportunity', 'clearly', '\n'],
#  ['fund', 'amazing', '\n'],
#  ['\n'],
#  ['look', 'feel', 'smell', 'like', 'macbook', '\n'],
#  ['unique', '\n'],
#  ['awesome', 'like', '\n'],
#  ['idea', 'like', 'know', '\n'],
#  ['success', 'macbook', 'air', '\n'],
#  ['like', 'let', 'replicate', 'sell', '\n'],
#  ['\n'],
#  ['macbook', 'clone', '\n'],
#  ['company', '\n'],
#  ['like', '\n'],
#  ['feel', 'like', 'need', '\n'],
#  ['feel', 'like', '\n'],
#  ['unique', 'design', 'like', '\n'],
#  ['know', 'macbook', '\n'],
#  ['complaint', '\n'],
#  ['slightly', '\n'],
#  ['different', 'kind', 'review', 'like', '\n'],
#  ['like', 'fact', '\n'],
#  ['macbook', 'clone', 'uh', '\n'],
#  ['thing', 'love', 'availability', '\n'],
#  ['right', 'available', '\n'],
#  ['mistaken', '\n'],
#  ['world', 'like', 'asia', 'north', 'america', '\n'],
#  ['little', '\n'],
#  ['\n'],
#  ['come', 'north', '\n'],
#  ['america', 'kind', 'pricing', '\n'],
#  ['disruptive', 'amazing', '\n'],
#  ['\n'],
#  ['import', 'stuff', '\n'],
#  ['\n'],
#  ['easily', 'available', '\n'],
#  ['\n'],
#  ['okay', 'hope', 'guy', '\n'],
#  ['enjoy', 'video', 'thumb', 'like', '\n'],
#  ['sub', 'love', 'guy', '\n'],
#  ['time', '\n'],
#  ['music']]

# %%
# Creates, which is a mapping of word IDs to words.
words = corpora.Dictionary(doc_list)

# Turns each document into a bag of words.
corpus = [words.doc2bow(doc) for doc in doc_list]

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=words,
                                           num_topics=5, 
                                           random_state=2,
                                           update_every=1,
                                           passes=3,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
pprint(lda_model.print_topics(num_words=10
))
# Out:
# [(0,
#   '0.134*"\n'
#   '" + 0.020*"open" + 0.019*"keyboard" + 0.019*"talk" + 0.019*"know" + '
#   '0.018*"let" + 0.018*"good" + 0.017*"like" + 0.014*"hour" + '
#   '0.014*"performance"'),
#  (1,
#   '0.085*"\n'
#   '" + 0.029*"macbook" + 0.024*"leave" + 0.022*"like" + 0.021*"rough" + '
#   '0.019*"edge" + 0.018*"clone" + 0.013*"replicate" + 0.013*"sell" + '
#   '0.013*"let"'),
#  (2,
#   '0.120*"\n'
#   '" + 0.036*"macbook" + 0.029*"keyboard" + 0.025*"ve" + 0.023*"look" + '
#   '0.022*"people" + 0.017*"thing" + 0.016*"like" + 0.015*"type" + '
#   '0.009*"high"'),
#  (3,
#   '0.263*"\n'
#   '" + 0.060*"like" + 0.023*"right" + 0.023*"thing" + 0.017*"kind" + '
#   '0.015*"screen" + 0.013*"good" + 0.012*"company" + 0.010*"device" + '
#   '0.010*"laptop"'),
#  (4,
#   '0.182*"\n'
#   '" + 0.019*"device" + 0.018*"usb" + 0.018*"kind" + 0.017*"point" + '
#   '0.015*"like" + 0.015*"cut" + 0.015*"macbook" + 0.014*"little" + 0.014*"c"')]
